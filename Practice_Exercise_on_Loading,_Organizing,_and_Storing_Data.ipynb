# %% [markdown]
# # <font face = 'Impact' color = '#FFAEBC' > Exercise on Loading, Organizing, and Storing Data<font/>
# #### <font face = 'Times New Roman' color = '#B5E5CF'> Licence: GPL v3.0 <font/>
# #### <font face = 'Times New Roman' color = '#B5E5CF'> Author and Trainer: Paolo Hilado MSc. (Data Science) <font/>
# Showcase your learning and skills by accomplishing this jupyter notebook. Follow through each of the tasks and code with python to address them.

# %% [markdown]
# #### <font face = 'Times New Roman' color = '#FFA384'> Submitted by: Jelena Jane A. Montuya <font/>
#
# #### <font face = 'Times New Roman' color = '#647FBC'> Year Level and Section: BSIS 4B <font/>
#
# #### <font face = 'Times New Roman' color = '#C6D870'> Date: September 5, 2025 <font/>

# %%
pip install researchpy

# %%
# Import the necesary libraries such as pandas, researchpy, os, and numpy.
import pandas as pd
import researchpy as rp
import os
import numpy as np

# %%
#Checking out the current working directory
print(os.getcwd())
# Out:
# /content/sample_data

# %%
os.chdir('/content/sample_data')

# %%
#Load a spreadsheet and assigning it to a variable df.
# Open and work on "ExperimentOne.xlsx".
df = pd.read_excel("ExperimentOne.xlsx")

# %%
#View the dataframe
df
# Out:
#     ID   Post  Group
# 0    1  17.23  Cntrl
# 1    2  16.04  Cntrl
# 2    3  19.22  Cntrl
# 3    4  19.45  Cntrl
# 4    5  18.53  Cntrl
# ..  ..    ...    ...
# 69  70   6.86     Tx
# 70  71  17.63     Tx
# 71  72  18.84     Tx
# 72  73  15.11     Tx
# 73  74  19.07     Tx
#
# [74 rows x 3 columns]

# %%
# Viewing the first 7 rows
df.head(7)
# Out:
#    ID   Post  Group
# 0   1  17.23  Cntrl
# 1   2  16.04  Cntrl
# 2   3  19.22  Cntrl
# 3   4  19.45  Cntrl
# 4   5  18.53  Cntrl
# 5   6  21.00  Cntrl
# 6   7  19.28  Cntrl

# %%
# Viewing the last 7 rows
df.tail(7)
# Out:
#     ID   Post Group
# 67  68  12.55    Tx
# 68  69  19.67    Tx
# 69  70   6.86    Tx
# 70  71  17.63    Tx
# 71  72  18.84    Tx
# 72  73  15.11    Tx
# 73  74  19.07    Tx

# %%
# Slice the data frame to only show the data on the "Post" Column.
sub = df.iloc[:,1]
sub
# Out:
# 0     17.23
# 1     16.04
# 2     19.22
# 3     19.45
# 4     18.53
#       ...
# 69     6.86
# 70    17.63
# 71    18.84
# 72    15.11
# 73    19.07
# Name: Post, Length: 74, dtype: float64

# %%
# Create different subsets of the data frame and show it.
sub1 = df.iloc[:, [0,2]]
print(sub1)

# Get the data for the first column
sub2 = df.iloc[:, 0]
print(sub2)
# Out:
#     ID  Group
# 0    1  Cntrl
# 1    2  Cntrl
# 2    3  Cntrl
# 3    4  Cntrl
# 4    5  Cntrl
# ..  ..    ...
# 69  70     Tx
# 70  71     Tx
# 71  72     Tx
# 72  73     Tx
# 73  74     Tx
#
# [74 rows x 2 columns]
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 69    70
# 70    71
# 71    72
# 72    73
# 73    74
# Name: ID, Length: 74, dtype: int64

# %%
# Get the Post Test and Group data for records 1-10
sub3 = df.iloc[1:11, 1:3]
sub3
# Out:
#      Post  Group
# 1   16.04  Cntrl
# 2   19.22  Cntrl
# 3   19.45  Cntrl
# 4   18.53  Cntrl
# 5   21.00  Cntrl
# 6   19.28  Cntrl
# 7   19.63  Cntrl
# 8   12.66  Cntrl
# 9   17.55  Cntrl
# 10  18.08  Cntrl

# %%
# Get the Post Test and Group data for records 7,11,15,50,61.
sub4 = df.iloc[[7,11,15,50,61], 1:3]
sub4
# Out:
#      Post  Group
# 7   19.63  Cntrl
# 11  16.55  Cntrl
# 15  21.04  Cntrl
# 50  18.58     Tx
# 61  16.41     Tx

# %%
# Check the information of the data frame such as number of records and features,
# data types of each feature and file size.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      74 non-null     int64
#  1   Post    74 non-null     float64
#  2   Group   74 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.9+ KB

# %%
#Checking for NAs or missing cases for the data set
df.isnull().values.any()
# Out:
# np.False_

# %%
# Check for NAs per column
missing_df2= df[df.isnull().any(axis=1)]

# %%
# Provide a descriptive analysis for the Post Test measure
desc = df.describe()
desc.T
# Out:
#       count       mean        std   min     25%     50%    75%    max
# ID     74.0  37.500000  21.505813  1.00  19.250  37.500  55.75  74.00
# Post   74.0  16.924324   3.344020  5.28  16.055  18.205  19.16  21.04

# %%
# Provide a descriptive analysis for Post Test measure per Group.
# Make sure that it is rounded to two decimal places only.
# Save this in the variable labeled results.
# Present the results variable

desc1 = df.groupby('Group').describe()
rounded = desc1.round(2)
result = rounded
result
# Out:
#          ID                                             Post               \
#       count  mean    std   min   25%   50%   75%   max count   mean   std
# Group
# Cntrl  37.0  19.0  10.82   1.0  10.0  19.0  28.0  37.0  37.0  17.23  3.52
# Tx     37.0  56.0  10.82  38.0  47.0  56.0  65.0  74.0  37.0  16.62  3.17
#
#
#         min    25%    50%    75%    max
# Group
# Cntrl  5.28  16.24  19.05  19.42  21.04
# Tx     6.86  16.01  17.63  18.55  20.83

# %% [markdown]
# Journal on Activity Excercise One
#
# 1. What were the problems that you encountered while accomplishing the excercise?
# * While completing the exercise, I encountered several issues related to loading libraries and managing variables in the code. Specifically, the researchpy library was not installed in my environment, which caused errors during execution. Additionally, I occasionally misspelled function names or unintentionally overwrote existing variables, resulting in incorrect outputs.
#
# 2. Cite the reason why you had these problems while doing the task.
# * These issues occurred primarily because researchpy had not been installed in Google Colab before running the analysis. Furthermore, some errors stemmed from typographical mistakes in the syntax of functions and from assigning duplicate names to different variables, which led to confusion and unexpected results.
#
# 3. List down your next set of actions so as not to encounter these problems again.
# * To prevent these issues from happening again, I plan to:
# Ensure that all required libraries are installed in the environment before starting the activity.
# Double-check the spelling and syntax of functions while coding to avoid typographical errors.
# Maintain a clear list or naming convention for variables to prevent duplication or accidental overwriting.
